# %% [raw]
# 1. Why are functions advantageous to have in your programs?
#
# Answer: By making function, we can increase the re-usability of the particular.Let's suppose we have to
# add 2-3 numbers many times within a code, we dont need to write again and again. We will just create a function
# and use call it whenever required.
#
#
# 2. When does the code in a function run: when it's specified or when it's called?
#
# Answer:When we call the function in code. We can specify it anywhere like wherever we want it.
# Ex:
#
# def func1(a): - Here we are defining the function.
#     return a**2;
#
# func1(2)- Here we are calling the function with it's name
#
#
# 3. What statement creates a function?
#
# Answer:
# def func():
#     pass
#
#
# 4. What is the difference between a function and a function call?
#
# Answer: def func():
#             pass
#
# Here func is a function and func() is a function call
#
# 5. How many global scopes are there in a Python program? How many local scopes?
#
# Answer: There can be 1 global scope and many local scopes i think
#
#
# 6. What happens to variables in a local scope when the function call returns?
#
# Answer:The value present inside the local scope will be return but the variable only remains within the local scope
#
#
# 7. What is the concept of a return value? Is it possible to have a return value in an expression?
#
# Answer: Basically, if you want the funtion to give something at the end of it , we use return value. Yes, it is possible
# to return value in an expression.
#
#
# 8. If a function does not have a return statement, what is the return value of a call to that function?
#
# Answer: Undefined
#
# 9. How do you make a function variable refer to the global variable?
#
# Answer: global variable_name
#
# 10. What is the data type of None?
#
# Answer: NoneType
#
# 11. What does the sentence import areallyourpetsnamederic do?
#
# Answer: Is it really a module?I doubt it
#
# 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?
#
# Answer:spam.bacon()
#
#
# 13. What can you do to save a programme from crashing if it encounters an error?
#
# Answer: Using try,except
#
# 14. What is the purpose of the try clause? What is the purpose of the except clause?
#
# Answer: The main purpose of try is to making the flow of the program go smoothly because if it encounter any
# error it just put the same on the except claue an doen not stop the whole program
#
# Tyre of error that might happer while executing the program comes under this like (Divide by zero error)
